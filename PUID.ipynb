# %% [markdown]
# <a href="https://colab.research.google.com/github/chaewoncutie/CCDATSCL_PROJECT_COM221/blob/main/PUID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# === YOUR INFORMATION ===
API_KEY = "RGAPI-7e9eecf0-b428-4f16-9cd9-8deed27237da"
GAME_NAME = "Wintermelon"
TAG_LINE = "Ella"
REGION = "asia"

# === GET PUUID ===
url = f"https://{REGION}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{GAME_NAME}/{TAG_LINE}"
headers = {"X-Riot-Token": API_KEY}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    MY_PUUID = data['puuid']
    print(f"✅ Success! Your PUUID is: {MY_PUUID}")
    print(f"\nSave this puuid to use in your filtering code!")
else:
    print(f"❌ Error {response.status_code}: {response.text}")
# Out:
# ✅ Success! Your PUUID is: JIByjp0oJk1zzKDopJHvnUsjtXcHvec-B04Kt5l-Tb7rxjzKupQ_R6X1WHHHAqHxTr1RBkE6wmvByQ
#
# Save this puuid to use in your filtering code!
